# %% [markdown]
# # DATA QUALITY ASSESSMENT
#
# * **Step 1** : Install Packages
# * **Step 2** : Reading Dataset & Loading to Dataframe
# * **Step 3** : Remove Data Quality Issues
# - 1) Unnecessary/Unwanted columns
# - 2) Inconsistent column names
# - 3) Missing values of unimportant columns
# - 4) Inconsistent values in columns (Accuracy)
# - 5) Duplicate Records (Uniqueness)
# - **Note** : "Check" has been used in the comment where dataframe info have been verified

# %%
#Step 1
#Install Packages
import pandas as pd
pd.options.mode.chained_assignment = None #To suppress the warning appeared while copying dataset to CustDemo_DS2
import numpy as np
import os

# %%
#To know which directory you are in
os. getcwd()
# Out:
# 'C:\\Users\\shwet\\OneDrive\\Desktop\\Shweta\\Skill Improve\\InsideSherpa\\KPMG'

# %%
#Step 2
#Reading Dataset
os.chdir(r"C:\Users\shwet\OneDrive\Desktop\Shweta\Skill Improve\InsideSherpa\KPMG")

# %% [markdown]
# # Customer Demographic - Data Cleaning

# %%
# Loading Dataset to Dataframe
# Customer Demographic
CustDemo_DS1= pd.read_excel('KPMG_VI_New_raw_data_update_final.xlsx', sheet_name='CustomerDemographic', parse_dates = True, encoding='utf8')
CustDemo_DS1
# Customer Address
CustAddr_DS1 = pd.read_excel('KPMG_VI_New_raw_data_update_final.xlsx',sheet_name='CustomerAddress',parse_dates=True,encoding='utf8')
CustAddr_DS1
# Transactions
Transact_DS1 = pd.read_excel('KPMG_VI_New_raw_data_update_final.xlsx', sheet_name='Transactions',parse_date=True,encoding='utf8')
Transact_DS1
# NewCustomerList
NewCustomerList_DS1 = pd.read_excel('KPMG_VI_New_raw_data_update_final.xlsx', sheet_name='NewCustomerList',parse_date=True,encoding='utf8')
NewCustomerList_DS1
# Out:
#     first_name  last_name  gender  past_3_years_bike_related_purchases  \
# 0      Chickie    Brister    Male                                   86
# 1        Morly     Genery    Male                                   69
# 2      Ardelis  Forrester  Female                                   10
# 3       Lucine      Stutt  Female                                   64
# 4      Melinda     Hadlee  Female                                   34
# ..         ...        ...     ...                                  ...
# 995  Ferdinand  Romanetti    Male                                   60
# 996       Burk    Wortley    Male                                   22
# 997   Melloney      Temby  Female                                   17
# 998     Dickie    Cubbini    Male                                   30
# 999      Sylas    Duffill    Male                                   56
#
#            DOB                     job_title job_industry_category  \
# ...

# %%
####### Check ###########
#To return top 5 (default) rows
CustDemo_DS1.head()
CustAddr_DS1.head()
Transact_DS1.head()
NewCustomerList_DS1.head()
# To return last 5 (default) rows
CustDemo_DS1.tail()
CustAddr_DS1.tail()
Transact_DS1.tail()
NewCustomerList_DS1.tail()
# Out:
#     first_name  last_name  gender  past_3_years_bike_related_purchases  \
# 995  Ferdinand  Romanetti    Male                                   60
# 996       Burk    Wortley    Male                                   22
# 997   Melloney      Temby  Female                                   17
# 998     Dickie    Cubbini    Male                                   30
# 999      Sylas    Duffill    Male                                   56
#
#            DOB                     job_title job_industry_category  \
# 995 1959-10-07                     Paralegal    Financial Services
# 996 2001-10-17        Senior Sales Associate                Health
# 997 1954-10-05  Budget/Accounting Analyst IV    Financial Services
# 998 1952-12-17             Financial Advisor    Financial Services
# 999 1955-10-02           Staff Accountant IV              Property
#
#         wealth_segment deceased_indicator owns_car  ...  state    country  \
# ...

# %% [markdown]
# ### Data Quality Issue 1 : Unnecessary Columns Removal

# %%
# To remove unnecessary columns: 
# DEFAULT in Customer Demographic
CustDemo_DS1.columns
CustDemo_DS2 = CustDemo_DS1.drop('default',axis=1,inplace=False)
CustDemo_DS2.head(2)
# no columns in Customer Address
CustAddr_DS1
# online_order in Transaction
Transact_DS1.columns
Transact_DS2 = Transact_DS1.drop(Transact_DS1.columns[[4]],axis=1,inplace=False)
Transact_DS2
# Unamed columns in NewCustomerList
NewCustomerList_DS1.columns
NewCustomerList_DS2 = NewCustomerList_DS1.drop(NewCustomerList_DS1.columns[[16,17,18,19,20]],axis=1,inplace=False)
NewCustomerList_DS2
# Out:
#     first_name  last_name  gender  past_3_years_bike_related_purchases  \
# 0      Chickie    Brister    Male                                   86
# 1        Morly     Genery    Male                                   69
# 2      Ardelis  Forrester  Female                                   10
# 3       Lucine      Stutt  Female                                   64
# 4      Melinda     Hadlee  Female                                   34
# ..         ...        ...     ...                                  ...
# 995  Ferdinand  Romanetti    Male                                   60
# 996       Burk    Wortley    Male                                   22
# 997   Melloney      Temby  Female                                   17
# 998     Dickie    Cubbini    Male                                   30
# 999      Sylas    Duffill    Male                                   56
#
#            DOB                     job_title job_industry_category  \
# ...

# %% [markdown]
# ### Data Quality Issue 2 : Inconsistent Column Removal

# %%
#Inconsistant column names
# Inconsistant upper/lower cases of columns
#Convert columns to upper case
#To assign upper case to columns
CustDemo_DS2.columns = CustDemo_DS2.columns.str.upper()
CustDemo_DS2.columns
CustDemo_DS2
# Can be Renamed the column names
#CustDemo_DS1.rename(columns = {'GENDER':'Gender'})
## Customer Address
CustAddr_DS1.columns
CustAddr_DS1.columns = CustAddr_DS1.columns.str.upper()
CustAddr_DS1
## Transaction
Transact_DS2.columns = Transact_DS2.columns.str.upper()
Transact_DS2
## NewCustomerList
NewCustomerList_DS2.columns = NewCustomerList_DS2.columns.str.upper()
NewCustomerList_DS2
# Out:
#     FIRST_NAME  LAST_NAME  GENDER  PAST_3_YEARS_BIKE_RELATED_PURCHASES  \
# 0      Chickie    Brister    Male                                   86
# 1        Morly     Genery    Male                                   69
# 2      Ardelis  Forrester  Female                                   10
# 3       Lucine      Stutt  Female                                   64
# 4      Melinda     Hadlee  Female                                   34
# ..         ...        ...     ...                                  ...
# 995  Ferdinand  Romanetti    Male                                   60
# 996       Burk    Wortley    Male                                   22
# 997   Melloney      Temby  Female                                   17
# 998     Dickie    Cubbini    Male                                   30
# 999      Sylas    Duffill    Male                                   56
#
#            DOB                     JOB_TITLE JOB_INDUSTRY_CATEGORY  \
# ...

# %% [markdown]
# ### Data Quality Issue 3 : Missing Values Removal/Replaced

# %%
######## Check #######
#Missing values interms of Integers i.e. number of missing values in each columns
#where False means No missing values

#Missing values interms of True/False 
#where False means No missing values
CustDemo_DS2.isnull()
CustDemo_DS2.isnull().any()
CustDemo_DS2.isna().any()
#For entire dataframe
CustDemo_DS2.isnull().any().any()
CustDemo_DS2.isna().any().any() 
CustDemo_DS2.isnull().sum()
CustDemo_DS2.isnull().sum().sum()
#### Customer Address
CustAddr_DS1.isnull()
CustAddr_DS1.isnull().any() # No null
CustAddr_DS1.isnull().sum()
CustAddr_DS1.isnull().sum().sum()
## Transaction
Transact_DS2.isnull().any().any()
Transact_DS2.isnull().sum().sum()
Transact_DS2.isnull().sum()
## NewCustomerList
NewCustomerList_DS2.isnull().any().any()
NewCustomerList_DS2.isnull().sum().sum()
NewCustomerList_DS2.isnull().sum()
# Out:
# FIRST_NAME                               0
# LAST_NAME                               29
# GENDER                                   0
# PAST_3_YEARS_BIKE_RELATED_PURCHASES      0
# DOB                                     17
# JOB_TITLE                              106
# JOB_INDUSTRY_CATEGORY                  165
# WEALTH_SEGMENT                           0
# DECEASED_INDICATOR                       0
# OWNS_CAR                                 0
# TENURE                                   0
# ADDRESS                                  0
# POSTCODE                                 0
# STATE                                    0
# COUNTRY                                  0
# PROPERTY_VALUATION                       0
# RANK                                     0
# VALUE                                    0
# dtype: int64

# %%
CustDemo_DS2.isnull().sum()
# Out:
# CUSTOMER_ID                              0
# FIRST_NAME                               0
# LAST_NAME                              125
# GENDER                                   0
# PAST_3_YEARS_BIKE_RELATED_PURCHASES      0
# DOB                                     87
# JOB_TITLE                              506
# JOB_INDUSTRY_CATEGORY                  656
# WEALTH_SEGMENT                           0
# DECEASED_INDICATOR                       0
# OWNS_CAR                                 0
# TENURE                                  87
# dtype: int64

# %%
#Adding a default value (imputation) OR Filling the missing values
#### 1) Missing values can be Fill NaN with value 0
#CustDemo_DS1.fillna(0)
#CustDemo_DS1_with0 = CustDemo_DS1.fillna(0)
#CustDemo_DS1_with0
#CustDemo_DS1['TENURE'].mean()
####### 2) To fill missing tenure values by mean
#CustDemo_DS1_withMEAN = CustDemo_DS1.TENURE.fillna(CustDemo_DS1['TENURE'].mean())
#CustDemo_DS1_withMEAN

# %%
CustDemo_DS2
##### CustDemo
# Column : TENURE missing values replace by 0
#CustDemo_DS2 = CustDemo_DS2.fillna({'TENURE':0},inplace=True)
CustDemo_DS2
CustDemo_DS3 = CustDemo_DS2[CustDemo_DS2['DOB'].notnull()]
CustDemo_DS3

#### Customer Address - no null

##### Transaction
Transact_DS3 = Transact_DS2[Transact_DS2['BRAND'].notnull()]
Transact_DS3

###### NewCustomerList
NewCustomerList_DS3 = NewCustomerList_DS2[NewCustomerList_DS2['DOB'].notnull()]
NewCustomerList_DS3
# Out:
#     FIRST_NAME  LAST_NAME  GENDER  PAST_3_YEARS_BIKE_RELATED_PURCHASES  \
# 0      Chickie    Brister    Male                                   86
# 1        Morly     Genery    Male                                   69
# 2      Ardelis  Forrester  Female                                   10
# 3       Lucine      Stutt  Female                                   64
# 4      Melinda     Hadlee  Female                                   34
# ..         ...        ...     ...                                  ...
# 995  Ferdinand  Romanetti    Male                                   60
# 996       Burk    Wortley    Male                                   22
# 997   Melloney      Temby  Female                                   17
# 998     Dickie    Cubbini    Male                                   30
# 999      Sylas    Duffill    Male                                   56
#
#            DOB                     JOB_TITLE JOB_INDUSTRY_CATEGORY  \
# ...

# %%
CustDemo_DS3.isnull().sum()
CustAddr_DS1.isnull.sum()
Transact_DS3.isnull().sum()
NewCustomerList_DS3.isnull().sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-38-00b825e434e7> in <module>
#       1 CustDemo_DS3.isnull().sum()
# ----> 2 CustAddr_DS1.isnull.sum()
#       3 Transact_DS3.isnull().sum()
#       4 NewCustomerList_DS3.isnull().sum()
#
# AttributeError: 'function' object has no attribute 'sum'

# %% [markdown]
# ### Data Quality Issue 4 :  Inconsistent values in columns

# %%
# Column : GENDER data transformed into F,M,U in place of Male, Female, Unmarried/Single
CustDemo_DS3['GENDER']
#type(CustDemo_DS1['GENDER'])
# to replce the values
CustDemo_DS3['GENDER'].replace(['Male','Female','Unavailable'],['M','F','U'],inplace=True)
CustDemo_DS3
# Customer Address
CustAddr_DS1['STATE']
CustAddr_DS1['STATE'].replace(['New South Wales','Queensland','Victoria'],['NSW','QLD','VIC'],inplace=True)
CustAddr_DS1
##### Transaction
Transact_DS3
### NewCustomerList
NewCustomerList_DS3['GENDER']
NewCustomerList_DS3['GENDER'].replace(['Male','Female','Unavailable'],['M','F','U'],inplace=True)
NewCustomerList_DS3

# %%
#To find total number of NAs NA
CustDemo_DS3.isnull().sum().sum()
#To check number of columns and rows
CustDemo_DS3.shape
######### Dropping NAs with conditions: 
########  axis-> 0-removes rows containing 0,1 - removes columns conatining 0 
########   how - all,any, thresh- int, subset
#CustDemo_DS1_dropNA_withcondition =CustDemo_DS1.dropna(how = 'any', thresh = 1)
#CustDemo_DS1_dropNA_withcondition.shape
#########   To get info about the dataframe
CustDemo_DS3.info()
CustDemo_DS3.isnull().sum()

# %% [markdown]
# ### Data Quality Issue 5 :  Duplicate Records

# %%
# Set - collection of unique columns
len(set(CustDemo_DS3))
# To have unique/distinct rows
CustDemo_DS_FINAL = CustDemo_DS3.drop_duplicates()
CustDemo_DS_FINAL.shape
# Customer Address
len(set(CustAddr_DS1))
CustAddr_DS_FINAL = CustAddr_DS1.drop_duplicates()
CustAddr_DS_FINAL.shape
#######
Transact_DS_FINAL = Transact_DS3.drop_duplicates()
Transact_DS_FINAL.shape
######
NewCustomerList_DS_FINAL = NewCustomerList_DS3.drop_duplicates()
NewCustomerList_DS_FINAL.shape
# Out:
# (983, 18)

# %%
### to chnage the data type 
NewCustomerList_DS_FINAL = NewCustomerList_DS_FINAL.astype({"TENURE": float})
NewCustomerList_DS_FINAL.info()

CustDemo_DS_FINAL
CustAddr_DS_FINAL
Transact_DS_FINAL
NewCustomerList_DS_FINAL
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 983 entries, 0 to 999
# Data columns (total 18 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   FIRST_NAME                           983 non-null    object
#  1   LAST_NAME                            954 non-null    object
#  2   GENDER                               983 non-null    object
#  3   PAST_3_YEARS_BIKE_RELATED_PURCHASES  983 non-null    int64
#  4   DOB                                  983 non-null    datetime64[ns]
#  5   JOB_TITLE                            878 non-null    object
#  6   JOB_INDUSTRY_CATEGORY                818 non-null    object
#  7   WEALTH_SEGMENT                       983 non-null    object
#  8   DECEASED_INDICATOR                   983 non-null    object
#  9   OWNS_CAR                             983 non-null    object
#  10  TENURE                               983 non-null    float64
# ...

# %%
# CustDemo_DS_FINAL.to_excel("Clean_RawDataset.xlsx",sheet_name="CustomerDemographic", startrow = 2, startcol=1)
# To write the final clean dataset to excel
with pd.ExcelWriter('Clean_Dataset.xlsx') as writer:
    CustDemo_DS_FINAL.to_excel(writer, sheet_name="CustDemo")
    CustAddr_DS_FINAL.to_excel(writer, sheet_name="CustAddr")
    Transact_DS_FINAL.to_excel(writer, sheet_name="Transact")
    NewCustomerList_DS_FINAL.to_excel(writer, sheet_name="NewCustomerList")

# %%
CustDemo_DS_FINAL.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3913 entries, 0 to 3912
# Data columns (total 12 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   CUSTOMER_ID                          3913 non-null   int64
#  1   FIRST_NAME                           3913 non-null   object
#  2   LAST_NAME                            3792 non-null   object
#  3   GENDER                               3913 non-null   object
#  4   PAST_3_YEARS_BIKE_RELATED_PURCHASES  3913 non-null   int64
#  5   DOB                                  3913 non-null   datetime64[ns]
#  6   JOB_TITLE                            3416 non-null   object
#  7   JOB_INDUSTRY_CATEGORY                3257 non-null   object
#  8   WEALTH_SEGMENT                       3913 non-null   object
#  9   DECEASED_INDICATOR                   3913 non-null   object
#  10  OWNS_CAR                             3913 non-null   object
# ...

# %%
CustAddr_DS_FINAL.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3999 entries, 0 to 3998
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   CUSTOMER_ID         3999 non-null   int64
#  1   ADDRESS             3999 non-null   object
#  2   POSTCODE            3999 non-null   int64
#  3   STATE               3999 non-null   object
#  4   COUNTRY             3999 non-null   object
#  5   PROPERTY_VALUATION  3999 non-null   int64
# dtypes: int64(3), object(3)
# memory usage: 218.7+ KB

# %%
Transact_DS_FINAL.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19803 entries, 0 to 19999
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   TRANSACTION_ID           19803 non-null  int64
#  1   PRODUCT_ID               19803 non-null  int64
#  2   CUSTOMER_ID              19803 non-null  int64
#  3   TRANSACTION_DATE         19803 non-null  datetime64[ns]
#  4   ORDER_STATUS             19803 non-null  object
#  5   BRAND                    19803 non-null  object
#  6   PRODUCT_LINE             19803 non-null  object
#  7   PRODUCT_CLASS            19803 non-null  object
#  8   PRODUCT_SIZE             19803 non-null  object
#  9   LIST_PRICE               19803 non-null  float64
#  10  STANDARD_COST            19803 non-null  float64
#  11  PRODUCT_FIRST_SOLD_DATE  19803 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), float64(2), int64(3), object(5)
# memory usage: 2.0+ MB

# %%
NewCustomerList_DS_FINAL.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 983 entries, 0 to 999
# Data columns (total 18 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   FIRST_NAME                           983 non-null    object
#  1   LAST_NAME                            954 non-null    object
#  2   GENDER                               983 non-null    object
#  3   PAST_3_YEARS_BIKE_RELATED_PURCHASES  983 non-null    int64
#  4   DOB                                  983 non-null    datetime64[ns]
#  5   JOB_TITLE                            878 non-null    object
#  6   JOB_INDUSTRY_CATEGORY                818 non-null    object
#  7   WEALTH_SEGMENT                       983 non-null    object
#  8   DECEASED_INDICATOR                   983 non-null    object
#  9   OWNS_CAR                             983 non-null    object
#  10  TENURE                               983 non-null    float64
# ...
